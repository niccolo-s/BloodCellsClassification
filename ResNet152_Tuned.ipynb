# %% [markdown]
# # ResNet50-based CNN model

# %% [markdown]
# ## Set working directory

# %%
from google.colab import drive

drive.mount('/gdrive')
# %cd /gdrive/My Drive/ # Set your directory

# %%
# %%writefile requirements.txt # These are needed to match libraries versions on Colab
# tensorflow==2.17.0
# keras==3.4.1
# pip install -r requirements.txt

# %%
model_name = 'ResNet152_tuned'

# %% [markdown]
# ## Import Libraries

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os
import setuptools.dist

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np
from tqdm.auto import tqdm

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import regularizers

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns
from PIL import Image
import matplotlib.gridspec as gridspec

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.17.0

# %% [markdown]
# ## Load data and split

# %%
import zipfile
from io import BytesIO

# Path to the zip file
zip_path = "./datasets.zip"

# Open the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # List all files in the zip archive
    file_names = zip_ref.namelist()
    print("Files in the zip archive:", file_names)

    # Load each .npz file
    datasets = {}
    for file_name in file_names:
        if file_name.endswith(".npz"):  # Ensure it's a .npz file
            with zip_ref.open(file_name) as npz_file:
                # Copy the file content into memory
                npz_data = BytesIO(npz_file.read())
                datasets[file_name] = np.load(npz_data)

    # Access the loaded data
    train_data = datasets["train.npz"]
    test_data = datasets["test.npz"]
    val_data = datasets["val.npz"]

X_train = train_data["images"]
y_train = train_data["labels"]

X_test = test_data["images"]
y_test = test_data["labels"]

X_val = val_data["images"]
y_val = val_data["labels"]

del train_data, test_data, val_data, datasets

# Define the mapping for the labels
label_names = {
    0: "Basophil",
    1: "Eosinophil",
    2: "Erythroblast",
    3: "Immature granulocytes",
    4: "Lymphocyte",
    5: "Monocyte",
    6: "Neutrophil",
    7: "Platelet"
}

# Input shape for the model
input_shape = X_train.shape[1:]

# Output shape for the model
output_shape = y_train.shape[1]
# Out:
# Files in the zip archive: ['train.npz', 'val.npz', 'test.npz']

# %% [markdown]
# # Model

# %% [markdown]
# ## Build the Model

# %%
# Set the hyperparameters

# Number of training epochs
epochs = 100

# patience
patience = 15

# Batch size for training
batch_size = 128

# Learning rate: step size for updating the model's weights
learning_rate = 1e-4

# number of fine-tunable layer
num_layers_to_unfreeze = 25

# %%
# Initialize the ResNet152 model
resnet_model = tf.keras.applications.ResNet152(
    input_shape=(224, 224, 3),   # Same input shape as MobileNetV3 example
    include_top=False,           # Exclude the fully connected layer for feature extraction
    weights='imagenet',                # No pretrained weights; start from scratch
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 ━━━━━━━━━━━━━━━━━━━━ 11s 0us/step

# %%
def build_model(
    input_shape = input_shape,
    output_shape = output_shape,
    learning_rate = learning_rate,
    seed = seed
):
  tf.random.set_seed(42)

  # Define input layer
  inputs = tf.keras.Input(shape=input_shape, name='input')
  x = tfkl.Resizing(224, 224)(inputs)

  # transfer learning
  x = tfk.applications.resnet.preprocess_input(x)

  # Keras tuner to determine the number of layers to unfreeze
  # Unfreeze the last 'num_layers_to_unfreeze' layers
  for layer in resnet_model.layers:
      layer.trainable = False

  trainable = num_layers_to_unfreeze

  conv_count = 0
  last_unfrozen_conv_idx = -1
  for i, layer in enumerate(reversed(resnet_model.layers)):
      if '_conv' in layer.name:
         if conv_count <= trainable :
            layer.trainable = True
            conv_count += 1
            last_unfrozen_conv_idx = len(resnet_model.layers) - 1 - i
         else:
            break

  if False:
     for i, layer in enumerate(resnet_model.layers[last_unfrozen_conv_idx + 1:], start=last_unfrozen_conv_idx + 1):
         if '_bn' in layer.name:
            layer.trainable = True


  x = resnet_model(x)

  x = tfkl.GlobalAveragePooling2D()(x)
  x = tfkl.BatchNormalization()(x)

  # Dense layers
  x = tfkl.Dense(units=1024,activation='relu',kernel_regularizer=regularizers.l2(1e-5))(x)
  x = tfkl.Dropout(0.4)(x)
  x = tfkl.BatchNormalization()(x)

  x = tfkl.Dense(units=128,activation='relu',kernel_regularizer=regularizers.l2(1e-5))(x)
  x = tfkl.Dropout(0.4)(x)
  x = tfkl.BatchNormalization()(x)

  # Add final Dense layer for classification with softmax activation
  outputs = tfkl.Dense(output_shape, activation='softmax')(x)

  # Create the complete Model linking input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='resnet_model_model')

  # Compile the model
  loss = tfk.losses.CategoricalCrossentropy()
  optimizer = tfk.optimizers.Adam(learning_rate=learning_rate)
  metrics = ['accuracy']
  model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

  return model

# %%
# Trace the weights' update
best_model_weights = tfk.callbacks.ModelCheckpoint(
    filepath = "./ResNet152_tuned/checkpoint.weights.h5",
    monitor='val_accuracy',
    mode = 'max',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    save_freq="epoch"
)

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Reduce the learning rate on plateu
learn_rate_reg = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1, patience=10,
    min_delta=1e-5
)

# Store the callback in a list
callbacks = [early_stopping, best_model_weights,learn_rate_reg]

# %%
model = build_model()

# Display a summary of the model architecture
model.summary(expand_nested=False)

# Display model architecture with layer shapes and trainable parameters
# tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "resnet_model_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)        │ (None, 96, 96, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ resizing (Resizing)       │ (None, 224, 224, 3)    │              0 │ input[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item (GetItem)        │ (None, 224, 224)       │              0 │ resizing[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_1 (GetItem)      │ (None, 224, 224)       │              0 │ resizing[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_2 (GetItem)      │ (None, 224, 224)       │              0 │ resizing[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stack (Stack)             │ (None, 224, 224, 3)    │              0 │ get_item[0][0],        │
# │                           │                        │                │ get_item_1[0][0],      │
# │                           │                        │                │ get_item_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 224, 224, 3)    │              0 │ stack[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ resnet152 (Functional)    │ (None, 7, 7, 2048)     │     58,370,944 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 2048)           │              0 │ resnet152[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 2048)           │          8,192 │ global_average_poolin… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1024)           │      2,098,176 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 1024)           │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 1024)           │          4,096 │ dropout[0][0]          │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 128)            │        131,200 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 128)            │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 128)            │            512 │ dropout_1[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 8)              │          1,032 │ batch_normalization_2… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 60,614,152 (231.22 MB)
#  Trainable params: 23,031,688 (87.86 MB)
#  Non-trainable params: 37,582,464 (143.37 MB)

# %% [markdown]
# ## Training

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_val, y_val),
    callbacks = callbacks
).history


# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')
# Out:
# Epoch 1/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.6239 - loss: 1.2215
# Epoch 1: val_accuracy improved from -inf to 0.84609, saving model to ./ResNet152_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 112s 204ms/step - accuracy: 0.6243 - loss: 1.2206 - val_accuracy: 0.8461 - val_loss: 0.5038 - learning_rate: 1.0000e-04
# Epoch 2/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8477 - loss: 0.5758
# Epoch 2: val_accuracy did not improve from 0.84609
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.8477 - loss: 0.5757 - val_accuracy: 0.8426 - val_loss: 0.5049 - learning_rate: 1.0000e-04
# Epoch 3/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8763 - loss: 0.4783
# Epoch 3: val_accuracy improved from 0.84609 to 0.88918, saving model to ./ResNet152_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 50s 138ms/step - accuracy: 0.8763 - loss: 0.4782 - val_accuracy: 0.8892 - val_loss: 0.3851 - learning_rate: 1.0000e-04
# Epoch 4/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8969 - loss: 0.4120
# Epoch 4: val_accuracy did not improve from 0.88918
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.8969 - loss: 0.4120 - val_accuracy: 0.8320 - val_loss: 0.5723 - learning_rate: 1.0000e-04
# Epoch 5/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9140 - loss: 0.3588
# Epoch 5: val_accuracy did not improve from 0.88918
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9140 - loss: 0.3588 - val_accuracy: 0.8575 - val_loss: 0.4973 - learning_rate: 1.0000e-04
# Epoch 6/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9285 - loss: 0.3163
# Epoch 6: val_accuracy did not improve from 0.88918
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9285 - loss: 0.3163 - val_accuracy: 0.8865 - val_loss: 0.5142 - learning_rate: 1.0000e-04
# Epoch 7/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9359 - loss: 0.2883
# Epoch 7: val_accuracy improved from 0.88918 to 0.91557, saving model to ./ResNet152_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 48s 132ms/step - accuracy: 0.9359 - loss: 0.2883 - val_accuracy: 0.9156 - val_loss: 0.3930 - learning_rate: 1.0000e-04
# Epoch 8/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9404 - loss: 0.2768
# Epoch 8: val_accuracy did not improve from 0.91557
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9404 - loss: 0.2768 - val_accuracy: 0.8892 - val_loss: 0.4826 - learning_rate: 1.0000e-04
# Epoch 9/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9452 - loss: 0.2584
# Epoch 9: val_accuracy did not improve from 0.91557
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9452 - loss: 0.2584 - val_accuracy: 0.8892 - val_loss: 0.5023 - learning_rate: 1.0000e-04
# Epoch 10/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9521 - loss: 0.2394
# Epoch 10: val_accuracy improved from 0.91557 to 0.92348, saving model to ./ResNet152_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 48s 130ms/step - accuracy: 0.9521 - loss: 0.2394 - val_accuracy: 0.9235 - val_loss: 0.3676 - learning_rate: 1.0000e-04
# Epoch 11/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9543 - loss: 0.2302
# Epoch 11: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 115ms/step - accuracy: 0.9544 - loss: 0.2302 - val_accuracy: 0.8962 - val_loss: 0.4157 - learning_rate: 1.0000e-04
# Epoch 12/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9554 - loss: 0.2281
# Epoch 12: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9554 - loss: 0.2281 - val_accuracy: 0.9217 - val_loss: 0.4045 - learning_rate: 1.0000e-04
# Epoch 13/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9563 - loss: 0.2215
# Epoch 13: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9563 - loss: 0.2215 - val_accuracy: 0.9208 - val_loss: 0.3644 - learning_rate: 1.0000e-04
# Epoch 14/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9604 - loss: 0.2142
# Epoch 14: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9604 - loss: 0.2142 - val_accuracy: 0.8901 - val_loss: 0.5045 - learning_rate: 1.0000e-04
# Epoch 15/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9588 - loss: 0.2153
# Epoch 15: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 41s 114ms/step - accuracy: 0.9588 - loss: 0.2153 - val_accuracy: 0.9112 - val_loss: 0.4166 - learning_rate: 1.0000e-04
# Epoch 16/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.9579 - loss: 0.2069
# Epoch 16: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 41s 114ms/step - accuracy: 0.9579 - loss: 0.2069 - val_accuracy: 0.9041 - val_loss: 0.4182 - learning_rate: 1.0000e-04
# Epoch 17/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9624 - loss: 0.1992
# Epoch 17: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9624 - loss: 0.1991 - val_accuracy: 0.9112 - val_loss: 0.4592 - learning_rate: 1.0000e-04
# Epoch 18/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9619 - loss: 0.1940
# Epoch 18: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 115ms/step - accuracy: 0.9619 - loss: 0.1940 - val_accuracy: 0.9217 - val_loss: 0.3801 - learning_rate: 1.0000e-04
# Epoch 19/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9603 - loss: 0.1926
# Epoch 19: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 115ms/step - accuracy: 0.9603 - loss: 0.1926 - val_accuracy: 0.8901 - val_loss: 0.5222 - learning_rate: 1.0000e-04
# Epoch 20/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9587 - loss: 0.2066
# Epoch 20: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 115ms/step - accuracy: 0.9587 - loss: 0.2066 - val_accuracy: 0.8804 - val_loss: 0.6056 - learning_rate: 1.0000e-04
# Epoch 21/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9619 - loss: 0.1944
# Epoch 21: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 115ms/step - accuracy: 0.9619 - loss: 0.1944 - val_accuracy: 0.9112 - val_loss: 0.4004 - learning_rate: 1.0000e-04
# Epoch 22/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9626 - loss: 0.1861
# Epoch 22: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 115ms/step - accuracy: 0.9626 - loss: 0.1861 - val_accuracy: 0.9120 - val_loss: 0.3824 - learning_rate: 1.0000e-04
# Epoch 23/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9628 - loss: 0.1877
# Epoch 23: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9628 - loss: 0.1877 - val_accuracy: 0.9235 - val_loss: 0.3860 - learning_rate: 1.0000e-04
# Epoch 24/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9643 - loss: 0.1784
# Epoch 24: val_accuracy improved from 0.92348 to 0.93316, saving model to ./ResNet152_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 50s 138ms/step - accuracy: 0.9643 - loss: 0.1784 - val_accuracy: 0.9332 - val_loss: 0.3591 - learning_rate: 1.0000e-05
# Epoch 25/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9676 - loss: 0.1730
# Epoch 25: val_accuracy did not improve from 0.93316
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9676 - loss: 0.1730 - val_accuracy: 0.9323 - val_loss: 0.3514 - learning_rate: 1.0000e-05
# Epoch 26/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9679 - loss: 0.1715
# Epoch 26: val_accuracy improved from 0.93316 to 0.93492, saving model to ./ResNet152_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 48s 131ms/step - accuracy: 0.9679 - loss: 0.1715 - val_accuracy: 0.9349 - val_loss: 0.3498 - learning_rate: 1.0000e-05
# Epoch 27/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9700 - loss: 0.1700
# Epoch 27: val_accuracy did not improve from 0.93492
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 115ms/step - accuracy: 0.9700 - loss: 0.1700 - val_accuracy: 0.9332 - val_loss: 0.3419 - learning_rate: 1.0000e-05
# Epoch 28/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9709 - loss: 0.1687
# Epoch 28: val_accuracy improved from 0.93492 to 0.93668, saving model to ./ResNet152_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 48s 131ms/step - accuracy: 0.9709 - loss: 0.1687 - val_accuracy: 0.9367 - val_loss: 0.3409 - learning_rate: 1.0000e-05
# Epoch 29/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9743 - loss: 0.1679
# Epoch 29: val_accuracy did not improve from 0.93668
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9743 - loss: 0.1679 - val_accuracy: 0.9349 - val_loss: 0.3486 - learning_rate: 1.0000e-05
# Epoch 30/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9734 - loss: 0.1670
# Epoch 30: val_accuracy did not improve from 0.93668
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9734 - loss: 0.1670 - val_accuracy: 0.9340 - val_loss: 0.3511 - learning_rate: 1.0000e-05
# Epoch 31/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9746 - loss: 0.1660
# Epoch 31: val_accuracy did not improve from 0.93668
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9746 - loss: 0.1659 - val_accuracy: 0.9340 - val_loss: 0.3447 - learning_rate: 1.0000e-05
# Epoch 32/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9754 - loss: 0.1654
# Epoch 32: val_accuracy did not improve from 0.93668
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9754 - loss: 0.1654 - val_accuracy: 0.9305 - val_loss: 0.3495 - learning_rate: 1.0000e-05
# Epoch 33/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9748 - loss: 0.1647
# Epoch 33: val_accuracy did not improve from 0.93668
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9748 - loss: 0.1647 - val_accuracy: 0.9323 - val_loss: 0.3482 - learning_rate: 1.0000e-05
# Epoch 34/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9757 - loss: 0.1642
# Epoch 34: val_accuracy did not improve from 0.93668
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 115ms/step - accuracy: 0.9757 - loss: 0.1642 - val_accuracy: 0.9349 - val_loss: 0.3510 - learning_rate: 1.0000e-05
# Epoch 35/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9749 - loss: 0.1640
# Epoch 35: val_accuracy improved from 0.93668 to 0.93755, saving model to ./ResNet152_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 48s 131ms/step - accuracy: 0.9749 - loss: 0.1640 - val_accuracy: 0.9376 - val_loss: 0.3440 - learning_rate: 1.0000e-05
# Epoch 36/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9763 - loss: 0.1633
# Epoch 36: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9763 - loss: 0.1633 - val_accuracy: 0.9314 - val_loss: 0.3450 - learning_rate: 1.0000e-05
# Epoch 37/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9765 - loss: 0.1629
# Epoch 37: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9765 - loss: 0.1629 - val_accuracy: 0.9340 - val_loss: 0.3453 - learning_rate: 1.0000e-05
# Epoch 38/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9765 - loss: 0.1629
# Epoch 38: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9765 - loss: 0.1629 - val_accuracy: 0.9305 - val_loss: 0.3544 - learning_rate: 1.0000e-05
# Epoch 39/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9760 - loss: 0.1624
# Epoch 39: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9760 - loss: 0.1624 - val_accuracy: 0.9305 - val_loss: 0.3552 - learning_rate: 1.0000e-06
# Epoch 40/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9757 - loss: 0.1621
# Epoch 40: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9758 - loss: 0.1621 - val_accuracy: 0.9314 - val_loss: 0.3564 - learning_rate: 1.0000e-06
# Epoch 41/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9778 - loss: 0.1617
# Epoch 41: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9778 - loss: 0.1617 - val_accuracy: 0.9314 - val_loss: 0.3564 - learning_rate: 1.0000e-06
# Epoch 42/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9778 - loss: 0.1618
# Epoch 42: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9778 - loss: 0.1618 - val_accuracy: 0.9305 - val_loss: 0.3551 - learning_rate: 1.0000e-06
# Epoch 43/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9772 - loss: 0.1617
# Epoch 43: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9772 - loss: 0.1617 - val_accuracy: 0.9314 - val_loss: 0.3556 - learning_rate: 1.0000e-06
# Epoch 44/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9772 - loss: 0.1614
# Epoch 44: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9772 - loss: 0.1614 - val_accuracy: 0.9314 - val_loss: 0.3563 - learning_rate: 1.0000e-06
# Epoch 45/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9779 - loss: 0.1615
# Epoch 45: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9779 - loss: 0.1615 - val_accuracy: 0.9314 - val_loss: 0.3555 - learning_rate: 1.0000e-06
# Epoch 46/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9776 - loss: 0.1610
# Epoch 46: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9776 - loss: 0.1610 - val_accuracy: 0.9305 - val_loss: 0.3538 - learning_rate: 1.0000e-06
# Epoch 47/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9780 - loss: 0.1610
# Epoch 47: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9780 - loss: 0.1610 - val_accuracy: 0.9314 - val_loss: 0.3552 - learning_rate: 1.0000e-06
# Epoch 48/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9775 - loss: 0.1609
# Epoch 48: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 114ms/step - accuracy: 0.9775 - loss: 0.1608 - val_accuracy: 0.9314 - val_loss: 0.3550 - learning_rate: 1.0000e-06
# Epoch 49/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9787 - loss: 0.1609
# Epoch 49: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 115ms/step - accuracy: 0.9787 - loss: 0.1609 - val_accuracy: 0.9314 - val_loss: 0.3545 - learning_rate: 1.0000e-07
# Epoch 50/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.9779 - loss: 0.1609
# Epoch 50: val_accuracy did not improve from 0.93755
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 42s 115ms/step - accuracy: 0.9779 - loss: 0.1609 - val_accuracy: 0.9305 - val_loss: 0.3549 - learning_rate: 1.0000e-07
# Final validation accuracy: 93.76%

# %%
# Save the trained model to a file with the accuracy included in the filename
model_filename = model_name + '_' + str(final_val_accuracy)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model

# %%
# Create figure and subplots for loss and accuracy
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 6), sharex=True)

# Plot training and validation loss
ax1.plot(history['loss'], label='Training loss', alpha=.8)
ax1.plot(history['val_loss'], label='Validation loss', alpha=.8)
ax1.set_title('Loss')
ax1.legend()
ax1.grid(alpha=.3)

# Plot training and validation accuracy
ax2.plot(history['accuracy'], label='Training accuracy', alpha=.8)
ax2.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
ax2.set_title('Accuracy')
ax2.legend()
ax2.grid(alpha=.3)

# Adjust the layout and display the plot
plt.tight_layout()
plt.subplots_adjust(right=0.85)
plt.show()

# %% [markdown]
# ## Testing

# %%
# Load the saved model
model = tfk.models.load_model(model_filename)

# Predict labels for the entire test set
predictions = model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Convert predictions to class labels
pred_classes = np.argmax(predictions, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy = accuracy_score(true_classes, pred_classes)
print(f'Accuracy score over the test set: {round(accuracy, 4)}')

# Calculate and display test set precision
precision = precision_score(true_classes, pred_classes, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Calculate and display test set recall
recall = recall_score(true_classes, pred_classes, average='weighted')
print(f'Recall score over the test set: {round(recall, 4)}')

# Calculate and display test set F1 score
f1 = f1_score(true_classes, pred_classes, average='weighted')
print(f'F1 score over the test set: {round(f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(true_classes, pred_classes)

# Combine numbers and percentages into a single string for annotation
annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(label_names.values()), yticklabels=list(label_names.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Predictions Shape: (598, 8)
# Accuracy score over the test set: 0.9398
# Precision score over the test set: 0.9402
# Recall score over the test set: 0.9398
# F1 score over the test set: 0.9398
