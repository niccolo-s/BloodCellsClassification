# %% [markdown]
# # ResNet50-based CNN model

# %% [markdown]
# ## Set working directory

# %%
from google.colab import drive

drive.mount('/gdrive')
# %cd /gdrive/My Drive/ # Set your directory

# %%
# %%writefile requirements.txt # These are needed to match libraries versions on Colab
# tensorflow==2.17.0
# keras==3.4.1
# pip install -r requirements.txt

# %%
model_name = 'ResNet50_tuned'

# %% [markdown]
# ## Import Libraries

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os
import setuptools.dist

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np
from tqdm.auto import tqdm

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import regularizers

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
import seaborn as sns
from PIL import Image
import matplotlib.gridspec as gridspec

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.17.0

# %% [markdown]
# ## Load data and split

# %%
import zipfile
from io import BytesIO

# Path to the zip file
zip_path = "./datasets.zip"

# Open the zip file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # List all files in the zip archive
    file_names = zip_ref.namelist()
    print("Files in the zip archive:", file_names)

    # Load each .npz file
    datasets = {}
    for file_name in file_names:
        if file_name.endswith(".npz"):  # Ensure it's a .npz file
            with zip_ref.open(file_name) as npz_file:
                # Copy the file content into memory
                npz_data = BytesIO(npz_file.read())
                datasets[file_name] = np.load(npz_data)

    # Access the loaded data
    train_data = datasets["train.npz"]
    test_data = datasets["test.npz"]
    val_data = datasets["val.npz"]

X_train = train_data["images"]
y_train = train_data["labels"]

X_test = test_data["images"]
y_test = test_data["labels"]

X_val = val_data["images"]
y_val = val_data["labels"]

del train_data, test_data, val_data, datasets

# Define the mapping for the labels
label_names = {
    0: "Basophil",
    1: "Eosinophil",
    2: "Erythroblast",
    3: "Immature granulocytes",
    4: "Lymphocyte",
    5: "Monocyte",
    6: "Neutrophil",
    7: "Platelet"
}

# Input shape for the model
input_shape = X_train.shape[1:]

# Output shape for the model
output_shape = y_train.shape[1]
# Out:
# Files in the zip archive: ['train.npz', 'val.npz', 'test.npz']

# %% [markdown]
# # Model

# %% [markdown]
# ## Build the Model

# %%
# Set the hyperparameters

# Number of training epochs
epochs = 100

# patience
patience = 15

# Batch size for training
batch_size = 128

# Learning rate: step size for updating the model's weights
learning_rate = 1e-4

# number of fine-tunable layer
num_layers_to_unfreeze = 10

# %%
# Initialize the EfficientNetB5 model
resnet_model = tf.keras.applications.ResNet50(
    input_shape=(224, 224, 3),   # Input shape for ResNet50
    include_top=False,           # Exclude the fully connected layer for feature extraction
    weights='imagenet',          # Use pre-trained weights from ImageNet
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
def build_model(
    input_shape = input_shape,
    output_shape = output_shape,
    learning_rate = learning_rate,
    seed = seed
):
  tf.random.set_seed(42)

  # Define input layer
  inputs = tf.keras.Input(shape=input_shape, name='input')
  x = tfkl.Resizing(224, 224)(inputs)

  # EfficientNet transfer learning
  x = tfk.applications.resnet50.preprocess_input(x)

  # Unfreeze the last 'num_layers_to_unfreeze' layers
  for layer in resnet_model.layers:
      layer.trainable = False

  trainable = num_layers_to_unfreeze

  conv_count = 0
  last_unfrozen_conv_idx = -1
  for i, layer in enumerate(reversed(resnet_model.layers)):
      if '_conv' in layer.name:
         if conv_count <= trainable :
            layer.trainable = True
            conv_count += 1
            last_unfrozen_conv_idx = len(resnet_model.layers) - 1 - i
         else:
            break

  if False:
     for i, layer in enumerate(resnet_model.layers[last_unfrozen_conv_idx + 1:], start=last_unfrozen_conv_idx + 1):
         if '_bn' in layer.name:
            layer.trainable = True


  x = resnet_model(x)

  x = tfkl.GlobalAveragePooling2D()(x)
  x = tfkl.BatchNormalization()(x)

  # Dense layers
  x = tfkl.Dense(units=1024,activation='relu',kernel_regularizer=regularizers.l2(1e-5))(x)
  x = tfkl.Dropout(0.4)(x)
  x = tfkl.BatchNormalization()(x)

  x = tfkl.Dense(units=128,activation='relu',kernel_regularizer=regularizers.l2(1e-5))(x)
  x = tfkl.Dropout(0.4)(x)
  x = tfkl.BatchNormalization()(x)

  # Add final Dense layer for classification with softmax activation
  outputs = tfkl.Dense(output_shape, activation='softmax')(x)

  # Create the complete Model linking input and output
  model = tfk.Model(inputs=inputs, outputs=outputs, name='resnet_model_model')

  # Compile the model
  loss = tfk.losses.CategoricalCrossentropy()
  optimizer = tfk.optimizers.Adam(learning_rate=learning_rate)
  metrics = ['accuracy']
  model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

  return model

# %%
# Trace the weights' update
best_model_weights = tfk.callbacks.ModelCheckpoint(
    filepath = "./ResNet50_tuned/checkpoint.weights.h5",
    monitor='val_accuracy',
    mode = 'max',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    save_freq="epoch"
)

# Create an EarlyStopping callback
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    patience=patience,
    restore_best_weights=True
)

# Reduce the learning rate on plateu
learn_rate_reg = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1, patience=10,
    min_delta=1e-5
)

# Store the callback in a list
callbacks = [early_stopping, best_model_weights, learn_rate_reg]

# %%
model = build_model()

# Display a summary of the model architecture
model.summary(expand_nested=False)

# Display model architecture with layer shapes and trainable parameters
# tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "resnet_model_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)        │ (None, 96, 96, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ resizing (Resizing)       │ (None, 224, 224, 3)    │              0 │ input[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item (GetItem)        │ (None, 224, 224)       │              0 │ resizing[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_1 (GetItem)      │ (None, 224, 224)       │              0 │ resizing[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_2 (GetItem)      │ (None, 224, 224)       │              0 │ resizing[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stack (Stack)             │ (None, 224, 224, 3)    │              0 │ get_item[0][0],        │
# │                           │                        │                │ get_item_1[0][0],      │
# │                           │                        │                │ get_item_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 224, 224, 3)    │              0 │ stack[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ resnet50 (Functional)     │ (None, 7, 7, 2048)     │     23,587,712 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 2048)           │              0 │ resnet50[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 2048)           │          8,192 │ global_average_poolin… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1024)           │      2,098,176 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 1024)           │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 1024)           │          4,096 │ dropout[0][0]          │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 128)            │        131,200 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 128)            │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 128)            │            512 │ dropout_1[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 8)              │          1,032 │ batch_normalization_2… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 25,830,920 (98.54 MB)
#  Trainable params: 17,453,448 (66.58 MB)
#  Non-trainable params: 8,377,472 (31.96 MB)

# %% [markdown]
# ## Training

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_data = (X_val, y_val),
    callbacks = callbacks
).history


# Calculate and print the final validation accuracy
final_val_accuracy = round(max(history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')
# Out:
# Epoch 1/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6372 - loss: 1.1802
# Epoch 1: val_accuracy improved from -inf to 0.85928, saving model to ./ResNet50_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 59s 110ms/step - accuracy: 0.6375 - loss: 1.1793 - val_accuracy: 0.8593 - val_loss: 0.4544 - learning_rate: 1.0000e-04
# Epoch 2/100
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8425 - loss: 0.5761
# Epoch 2: val_accuracy improved from 0.85928 to 0.86983, saving model to ./ResNet50_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.8425 - loss: 0.5760 - val_accuracy: 0.8698 - val_loss: 0.4595 - learning_rate: 1.0000e-04
# Epoch 3/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8820 - loss: 0.4630
# Epoch 3: val_accuracy did not improve from 0.86983
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.8820 - loss: 0.4629 - val_accuracy: 0.8698 - val_loss: 0.4168 - learning_rate: 1.0000e-04
# Epoch 4/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9075 - loss: 0.3869
# Epoch 4: val_accuracy did not improve from 0.86983
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9076 - loss: 0.3868 - val_accuracy: 0.8654 - val_loss: 0.4568 - learning_rate: 1.0000e-04
# Epoch 5/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9240 - loss: 0.3335
# Epoch 5: val_accuracy improved from 0.86983 to 0.89974, saving model to ./ResNet50_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.9240 - loss: 0.3335 - val_accuracy: 0.8997 - val_loss: 0.3896 - learning_rate: 1.0000e-04
# Epoch 6/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9348 - loss: 0.3016
# Epoch 6: val_accuracy did not improve from 0.89974
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9348 - loss: 0.3016 - val_accuracy: 0.8663 - val_loss: 0.5561 - learning_rate: 1.0000e-04
# Epoch 7/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9434 - loss: 0.2810
# Epoch 7: val_accuracy did not improve from 0.89974
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9434 - loss: 0.2810 - val_accuracy: 0.8610 - val_loss: 0.5948 - learning_rate: 1.0000e-04
# Epoch 8/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9448 - loss: 0.2728
# Epoch 8: val_accuracy improved from 0.89974 to 0.90765, saving model to ./ResNet50_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.9448 - loss: 0.2727 - val_accuracy: 0.9077 - val_loss: 0.4046 - learning_rate: 1.0000e-04
# Epoch 9/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9550 - loss: 0.2460
# Epoch 9: val_accuracy did not improve from 0.90765
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9550 - loss: 0.2460 - val_accuracy: 0.8980 - val_loss: 0.4738 - learning_rate: 1.0000e-04
# Epoch 10/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9566 - loss: 0.2339
# Epoch 10: val_accuracy did not improve from 0.90765
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9566 - loss: 0.2339 - val_accuracy: 0.8865 - val_loss: 0.5467 - learning_rate: 1.0000e-04
# Epoch 11/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9571 - loss: 0.2295
# Epoch 11: val_accuracy improved from 0.90765 to 0.90941, saving model to ./ResNet50_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.9571 - loss: 0.2294 - val_accuracy: 0.9094 - val_loss: 0.4438 - learning_rate: 1.0000e-04
# Epoch 12/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9590 - loss: 0.2216
# Epoch 12: val_accuracy did not improve from 0.90941
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9590 - loss: 0.2216 - val_accuracy: 0.9094 - val_loss: 0.4427 - learning_rate: 1.0000e-04
# Epoch 13/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9571 - loss: 0.2228
# Epoch 13: val_accuracy did not improve from 0.90941
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9572 - loss: 0.2227 - val_accuracy: 0.8945 - val_loss: 0.5214 - learning_rate: 1.0000e-04
# Epoch 14/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9592 - loss: 0.2140
# Epoch 14: val_accuracy did not improve from 0.90941
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9592 - loss: 0.2139 - val_accuracy: 0.9015 - val_loss: 0.4448 - learning_rate: 1.0000e-04
# Epoch 15/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9630 - loss: 0.2055
# Epoch 15: val_accuracy did not improve from 0.90941
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9630 - loss: 0.2055 - val_accuracy: 0.9068 - val_loss: 0.4511 - learning_rate: 1.0000e-04
# Epoch 16/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9644 - loss: 0.1962
# Epoch 16: val_accuracy improved from 0.90941 to 0.91909, saving model to ./ResNet50_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 23s 62ms/step - accuracy: 0.9644 - loss: 0.1962 - val_accuracy: 0.9191 - val_loss: 0.3892 - learning_rate: 1.0000e-05
# Epoch 17/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9673 - loss: 0.1869
# Epoch 17: val_accuracy did not improve from 0.91909
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9673 - loss: 0.1868 - val_accuracy: 0.9191 - val_loss: 0.3913 - learning_rate: 1.0000e-05
# Epoch 18/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9692 - loss: 0.1840
# Epoch 18: val_accuracy did not improve from 0.91909
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9692 - loss: 0.1839 - val_accuracy: 0.9191 - val_loss: 0.3900 - learning_rate: 1.0000e-05
# Epoch 19/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9703 - loss: 0.1817
# Epoch 19: val_accuracy improved from 0.91909 to 0.91996, saving model to ./ResNet50_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.9702 - loss: 0.1817 - val_accuracy: 0.9200 - val_loss: 0.3916 - learning_rate: 1.0000e-05
# Epoch 20/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9700 - loss: 0.1795
# Epoch 20: val_accuracy did not improve from 0.91996
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9700 - loss: 0.1795 - val_accuracy: 0.9200 - val_loss: 0.3988 - learning_rate: 1.0000e-05
# Epoch 21/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9705 - loss: 0.1787
# Epoch 21: val_accuracy improved from 0.91996 to 0.92084, saving model to ./ResNet50_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 24s 65ms/step - accuracy: 0.9705 - loss: 0.1786 - val_accuracy: 0.9208 - val_loss: 0.3959 - learning_rate: 1.0000e-05
# Epoch 22/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9725 - loss: 0.1771
# Epoch 22: val_accuracy improved from 0.92084 to 0.92172, saving model to ./ResNet50_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.9725 - loss: 0.1771 - val_accuracy: 0.9217 - val_loss: 0.3941 - learning_rate: 1.0000e-05
# Epoch 23/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9734 - loss: 0.1751
# Epoch 23: val_accuracy did not improve from 0.92172
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9734 - loss: 0.1751 - val_accuracy: 0.9200 - val_loss: 0.4019 - learning_rate: 1.0000e-05
# Epoch 24/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9714 - loss: 0.1748
# Epoch 24: val_accuracy did not improve from 0.92172
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9714 - loss: 0.1748 - val_accuracy: 0.9182 - val_loss: 0.4043 - learning_rate: 1.0000e-05
# Epoch 25/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9732 - loss: 0.1736
# Epoch 25: val_accuracy improved from 0.92172 to 0.92348, saving model to ./ResNet50_tuned/checkpoint.weights.h5
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 23s 64ms/step - accuracy: 0.9732 - loss: 0.1736 - val_accuracy: 0.9235 - val_loss: 0.4033 - learning_rate: 1.0000e-05
# Epoch 26/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9741 - loss: 0.1729
# Epoch 26: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9741 - loss: 0.1729 - val_accuracy: 0.9235 - val_loss: 0.4031 - learning_rate: 1.0000e-05
# Epoch 27/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9744 - loss: 0.1721
# Epoch 27: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 20s 53ms/step - accuracy: 0.9744 - loss: 0.1721 - val_accuracy: 0.9226 - val_loss: 0.4058 - learning_rate: 1.0000e-06
# Epoch 28/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9737 - loss: 0.1713
# Epoch 28: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.9737 - loss: 0.1713 - val_accuracy: 0.9226 - val_loss: 0.4067 - learning_rate: 1.0000e-06
# Epoch 29/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9732 - loss: 0.1714
# Epoch 29: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.9732 - loss: 0.1714 - val_accuracy: 0.9235 - val_loss: 0.4065 - learning_rate: 1.0000e-06
# Epoch 30/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9736 - loss: 0.1710
# Epoch 30: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.9736 - loss: 0.1710 - val_accuracy: 0.9226 - val_loss: 0.4072 - learning_rate: 1.0000e-06
# Epoch 31/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9742 - loss: 0.1707
# Epoch 31: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9742 - loss: 0.1707 - val_accuracy: 0.9208 - val_loss: 0.4066 - learning_rate: 1.0000e-06
# Epoch 32/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9752 - loss: 0.1707
# Epoch 32: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9752 - loss: 0.1707 - val_accuracy: 0.9208 - val_loss: 0.4069 - learning_rate: 1.0000e-06
# Epoch 33/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9728 - loss: 0.1704
# Epoch 33: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9728 - loss: 0.1704 - val_accuracy: 0.9235 - val_loss: 0.4054 - learning_rate: 1.0000e-06
# Epoch 34/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9737 - loss: 0.1699
# Epoch 34: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9737 - loss: 0.1699 - val_accuracy: 0.9226 - val_loss: 0.4069 - learning_rate: 1.0000e-06
# Epoch 35/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9736 - loss: 0.1700
# Epoch 35: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9736 - loss: 0.1700 - val_accuracy: 0.9217 - val_loss: 0.4073 - learning_rate: 1.0000e-06
# Epoch 36/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9749 - loss: 0.1698
# Epoch 36: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9749 - loss: 0.1698 - val_accuracy: 0.9235 - val_loss: 0.4084 - learning_rate: 1.0000e-06
# Epoch 37/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9764 - loss: 0.1699
# Epoch 37: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.9764 - loss: 0.1699 - val_accuracy: 0.9235 - val_loss: 0.4087 - learning_rate: 1.0000e-07
# Epoch 38/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9741 - loss: 0.1700
# Epoch 38: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9741 - loss: 0.1700 - val_accuracy: 0.9235 - val_loss: 0.4085 - learning_rate: 1.0000e-07
# Epoch 39/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9768 - loss: 0.1696
# Epoch 39: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 53ms/step - accuracy: 0.9768 - loss: 0.1696 - val_accuracy: 0.9226 - val_loss: 0.4091 - learning_rate: 1.0000e-07
# Epoch 40/100
# 364/365 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9751 - loss: 0.1696
# Epoch 40: val_accuracy did not improve from 0.92348
# 365/365 ━━━━━━━━━━━━━━━━━━━━ 19s 52ms/step - accuracy: 0.9751 - loss: 0.1696 - val_accuracy: 0.9235 - val_loss: 0.4086 - learning_rate: 1.0000e-07
# Final validation accuracy: 92.35%

# %%
# Save the trained model to a file with the accuracy included in the filename
model_filename = model_name + '_' + str(final_val_accuracy)+'.keras'
model.save(model_filename)

# Delete the model to free up resources
del model

# %%
# Create figure and subplots for loss and accuracy
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 6), sharex=True)

# Plot training and validation loss
ax1.plot(history['loss'], label='Training loss', alpha=.8)
ax1.plot(history['val_loss'], label='Validation loss', alpha=.8)
ax1.set_title('Loss')
ax1.legend()
ax1.grid(alpha=.3)

# Plot training and validation accuracy
ax2.plot(history['accuracy'], label='Training accuracy', alpha=.8)
ax2.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
ax2.set_title('Accuracy')
ax2.legend()
ax2.grid(alpha=.3)

# Adjust the layout and display the plot
plt.tight_layout()
plt.subplots_adjust(right=0.85)
plt.show()

# %% [markdown]
# ## Testing

# %%
# Load the saved model
model = tfk.models.load_model(model_filename)

# Predict labels for the entire test set
predictions = model.predict(X_test, verbose=0)

# Display the shape of the predictions
print("Predictions Shape:", predictions.shape)

# Convert predictions to class labels
pred_classes = np.argmax(predictions, axis=-1)

# Extract ground truth classes
true_classes = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
accuracy = accuracy_score(true_classes, pred_classes)
print(f'Accuracy score over the test set: {round(accuracy, 4)}')

# Calculate and display test set precision
precision = precision_score(true_classes, pred_classes, average='weighted')
print(f'Precision score over the test set: {round(precision, 4)}')

# Calculate and display test set recall
recall = recall_score(true_classes, pred_classes, average='weighted')
print(f'Recall score over the test set: {round(recall, 4)}')

# Calculate and display test set F1 score
f1 = f1_score(true_classes, pred_classes, average='weighted')
print(f'F1 score over the test set: {round(f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(true_classes, pred_classes)

# Combine numbers and percentages into a single string for annotation
annot = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm.T, annot=annot, fmt='', xticklabels=list(label_names.values()), yticklabels=list(label_names.values()), cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Predictions Shape: (598, 8)
# Accuracy score over the test set: 0.9314
# Precision score over the test set: 0.9323
# Recall score over the test set: 0.9314
# F1 score over the test set: 0.9314
